# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgns407/MaritimeDataMining/blob/2nd-week/TestType2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#TestType2**

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")
print(df)
# Out:
#       id    age city    f1  f2      f3    f4         f5  subscribed   views
# 0   id01    2.0   서울   NaN   0    gold  ENFJ  91.297791  2021-07-16  6820.0
# 1   id02    9.0   서울  70.0   1     NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2   id03   27.0   서울  61.0   1    gold  ISTJ  17.252986  2021-03-16  7312.0
# 3   id04   75.0   서울   NaN   2     NaN  INFP  52.667078  2021-07-21   493.0
# 4   id05   24.0   서울  85.0   2     NaN  ISFJ  29.269869  2021-03-07  1338.0
# ..   ...    ...  ...   ...  ..     ...   ...        ...         ...     ...
# 95  id95   77.0   경기  43.0   1    gold  INTJ  91.297791  2021-05-21  8697.0
# 96  id96   92.0   경기  53.0   1  silver  ENTJ  52.667078  2021-05-06  4336.0
# 97  id97  100.0   경기   NaN   0    gold  INFP  67.886373  2021-03-18  6687.0
# 98  id98   39.0   경기  58.0   2     NaN  INFP  98.429899  2021-10-02   865.0
# 99  id99    1.0   경기  47.0   0    gold  ESFJ  97.381034  2021-12-02  6090.0
#
# [100 rows x 10 columns]

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

print(std,mean,sep="\n")
# Out:
# 30.442758522588697
# 50.963

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

# 2) 이상치 최저, 최고 기준 구하기
lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

print(lower,upper,sep="\n")
# Out:
# 5.298862216116952
# 96.62713778388306

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

# 2) 이상치 최저, 최고 기준 구하기
lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

# 3) 이상치를 벗어나는 값(조건) 찾기
cond1 = df['age'] < lower
cond2 = df['age'] > upper

print(cond1,cond2)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: age, Length: 100, dtype: bool 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97     True
# 98    False
# 99    False
# Name: age, Length: 100, dtype: bool

# %%
pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

# 2) 이상치 최저, 최고 기준 구하기
lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

# 3) 이상치를 벗어나는 값(조건) 찾기
cond1 = df['age'] < lower
cond2 = df['age'] > upper

print(df[cond1|cond2]['age'])
# Out:
# 0       2.0
# 8       3.3
# 22     -6.3
# 29    -13.5
# 37    100.0
# 45     97.0
# 52     97.0
# 57      3.0
# 58      0.0
# 70     -9.0
# 86      2.0
# 92     97.0
# 97    100.0
# 99      1.0
# Name: age, dtype: float64

# %%
pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

# 2) 이상치 최저, 최고 기준 구하기
lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

# 3) 이상치를 벗어나는 값(조건) 찾기
cond1 = df['age'] < lower
cond2 = df['age'] > upper

# 4) 조건에 만족하는 이상치 age합
print(df[cond1|cond2]['age'].sum())
# Out:
# 473.5
