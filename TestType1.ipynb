# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgns407/MaritimeDataMining/blob/2nd-week/TestType1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **#TestType1**

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")
print(df)
# Out:
#       id    age city    f1  f2      f3    f4         f5  subscribed   views
# 0   id01    2.0   서울   NaN   0    gold  ENFJ  91.297791  2021-07-16  6820.0
# 1   id02    9.0   서울  70.0   1     NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2   id03   27.0   서울  61.0   1    gold  ISTJ  17.252986  2021-03-16  7312.0
# 3   id04   75.0   서울   NaN   2     NaN  INFP  52.667078  2021-07-21   493.0
# 4   id05   24.0   서울  85.0   2     NaN  ISFJ  29.269869  2021-03-07  1338.0
# ..   ...    ...  ...   ...  ..     ...   ...        ...         ...     ...
# 95  id95   77.0   경기  43.0   1    gold  INTJ  91.297791  2021-05-21  8697.0
# 96  id96   92.0   경기  53.0   1  silver  ENTJ  52.667078  2021-05-06  4336.0
# 97  id97  100.0   경기   NaN   0    gold  INFP  67.886373  2021-03-18  6687.0
# 98  id98   39.0   경기  58.0   2     NaN  INFP  98.429899  2021-10-02   865.0
# 99  id99    1.0   경기  47.0   0    gold  ESFJ  97.381034  2021-12-02  6090.0
#
# [100 rows x 10 columns]

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]
print(df)
# Out:
#       id   age city    f1  f2    f3    f4         f5  subscribed   views
# 0   id01   2.0   서울   NaN   0  gold  ENFJ  91.297791  2021-07-16  6820.0
# 1   id02   9.0   서울  70.0   1   NaN  ENFJ  60.339826  2021-05-12  2534.0
# 2   id03  27.0   서울  61.0   1  gold  ISTJ  17.252986  2021-03-16  7312.0
# 3   id04  75.0   서울   NaN   2   NaN  INFP  52.667078  2021-07-21   493.0
# 4   id05  24.0   서울  85.0   2   NaN  ISFJ  29.269869  2021-03-07  1338.0
# ..   ...   ...  ...   ...  ..   ...   ...        ...         ...     ...
# 75  id75  63.0   경기  47.0   0  gold  ESTP  20.129444  2021-06-12  6779.0
# 76  id76  71.0   경기  12.0   0   NaN  ENTJ  83.685380  2021-07-28  2872.0
# 77  id77  77.0   경기  31.0   0   NaN  INFP  98.429899  2021-01-16  1518.0
# 78  id78  92.0   경기  96.0   1  gold  INTJ  69.730313  2021-10-27  7565.0
# 79  id79  30.0   경기   NaN   0  gold  INTJ  80.138280  2021-08-14  8777.0
#
# [80 rows x 10 columns]

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
std1 = df['f1'].std()
print(std1)
# Out:
# 20.574853076621935

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
std1 = df['f1'].std()

# 3) 중앙값으로 결측치 채우기
med=df['f1'].median()
df['f1'] = df['f1'].fillna(med)
print(med)
print(df['f1'])
# Out:
# 68.0
# 0     68.0
# 1     70.0
# 2     61.0
# 3     68.0
# 4     85.0
#       ...
# 75    47.0
# 76    12.0
# 77    31.0
# 78    96.0
# 79    68.0
# Name: f1, Length: 80, dtype: float64

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
std1 = df['f1'].std()

# 3) 중앙값으로 결측치 채우기
med=df['f1'].median()
df['f1'] = df['f1'].fillna(med)

# 4) 결측치를 채운 후 'f1' 컬럼 표준편차 구하기
std2 = df['f1'].std()

print(std2)
# Out:
# 17.010788646613275

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
std1 = df['f1'].std()

# 3) 중앙값으로 결측치 채우기
med=df['f1'].median()
df['f1'] = df['f1'].fillna(med)

# 4) 결측치를 채운 후 'f1' 컬럼 표준편차 구하기
std2 = df['f1'].std()

# 5) 두 표준편차 차이 절대값 계산 (반올림하여 소수 둘째자리까지 계산)
result = abs(std1-std2)
print(round(result,2))
# Out:
# 3.56
