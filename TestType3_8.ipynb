# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgns407/MaritimeDataMining/blob/3rd-week/TestType3_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  [문제 3]

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0), 밑으로 가# 면서 제거하니, 행을 제거하는 것임.
df = df.dropna()
#.dropna >> 결측값 포함된 레이블 제거
print(df)
# Out:
#        id   age city     f1  f2      f3    f4         f5  subscribed    views
# 2    id03  27.0   서울   61.0   1    gold  ISTJ  17.252986  2021-03-16   7312.0
# 5    id06  22.0   서울   57.0   0     vip  INTP  20.129444  2021-09-12  21550.0
# 7    id08  38.0   서울  101.0   1  silver  INFJ  83.685380  2021-03-06   3260.0
# 9    id10  95.0   서울   74.0   1    gold  ISFP  98.429899  2021-04-03   9992.0
# 10  id100  47.0   경기   53.0   0     vip  ESFP  33.308999  2021-02-21  15535.0
# 11   id11  40.0   서울   68.0   0    gold  ENFP  98.429899  2021-10-29   6752.0
# 13   id13  15.0   서울   68.0   0    gold  ESFJ  83.685380  2021-12-30   5643.0
# 14   id14  77.0   서울   50.0   1    gold  ENTJ  67.886373  2021-09-19   5700.0
# 15   id15  22.0   서울   67.0   1    gold  ENTP   9.796378  2021-05-26   7676.0
# 16   id16  68.0   서울   85.0   0    gold  ESFP  16.283854  2021-07-25   9472.0
# 18   id18  41.0   서울   87.0   2    gold  ISFJ  80.138280  2021-03-03   7933.0
# 22   id22  -6.3   부산   72.0   1    gold  ENFP  52.667078  2021-02-09   6147.0
# 23   id23  34.0   부산   75.0   1    gold  ISTP  69.730313  2021-05-21   6236.0
# 24   id24  80.0   부산   44.0   0    gold  INFJ  73.586397  2021-09-11   5976.0
# 26   id26  55.0   부산   57.0   1    gold  ENFP  83.685380  2021-05-01   5857.0
# 27   id27  37.0   부산   60.0   0  silver  ESTP  73.586397  2021-10-13   4255.0
# 28   id28  38.0   부산   34.0   1    gold  ENTP  80.138280  2021-10-31   5068.0
# 29   id29 -13.5   부산   47.0   2    gold  ENTP  67.886373  2021-08-28   6793.0
# 31   id31  86.0   부산   77.0   0    gold  ESFJ  73.586397  2021-02-11   8014.0
# 32   id32  25.0   부산   64.0   0     vip  ISFJ  13.049921  2021-05-24  17421.0
# 33   id33  47.0   부산   94.0   0  silver  ENFJ  17.252986  2021-04-02   3880.0
# 36   id36  68.0   부산   77.0   1    gold  INTP  13.049921  2021-07-20   9713.0
# 40   id40  56.0   대구   75.0   0    gold  ENFP  17.252986  2021-01-22   8481.0
# 41   id41  81.0   대구   55.0   0    gold  ENFJ  37.113739  2021-10-04   8640.0
# 42   id42  65.0   대구   48.0   2    gold  ESTP  33.308999  2021-02-09   5999.0
# 43   id43  23.0   대구   60.0   0  silver  ISTP  29.269869  2021-05-18   3878.0
# 45   id45  97.0   대구   88.0   0    gold  ENFJ  13.049921  2021-06-21   8317.0
# 47   id47  34.6   대구   75.0   1    gold  ESTJ  90.496999  2021-05-28   8628.0
# 49   id49  75.0   대구   88.0   0    gold  INTP  37.113739  2021-03-31   9737.0
# 52   id52  97.0   대구   82.0   1    gold  ISFJ  90.496999  2021-05-20   8518.0
# 53   id53  52.0   대구   50.0   0    gold  ESTP  20.129444  2021-09-09   7012.0
# 55   id55  75.0   대구   63.0   2    gold  ENTP  13.049921  2021-02-06   6042.0
# 57   id57   3.0   대구  111.0   0  silver  ISFJ  29.269869  2021-01-12   4421.0
# 63   id63  88.0   경기   86.0   1  silver  ISFJ  73.586397  2021-12-01   4053.0
# 64   id64  43.0   경기   62.0   2    gold  ESFP  73.586397  2021-02-22   5995.0
# 68   id68  35.0   경기   45.0   2    gold  ISFP  67.886373  2021-07-29   8599.0
# 70   id70  -9.0   경기   96.0   1  silver  ISTP  48.431184  2021-11-17   4442.0
# 71   id71  35.0   경기   84.0   2    gold  ISFP  52.667078  2021-07-15   8087.0
# 74   id74  45.0   경기   98.0   0    gold  ESTP  52.667078  2021-05-27   7739.0
# 75   id75  63.0   경기   47.0   0    gold  ESTP  20.129444  2021-06-12   6779.0
# 78   id78  92.0   경기   96.0   1    gold  INTJ  69.730313  2021-10-27   7565.0
# 80   id80  67.0   경기   60.0   0  silver  ISFP  83.685380  2021-01-14   4381.0
# 83   id83  73.0   경기   50.0   1     vip  ENTP  80.138280  2021-09-26  19139.0
# 84   id84  66.0   경기   44.0   0    gold  INTP  83.685380  2021-12-19   5650.0
# 85   id85  83.6   경기   55.0   0    gold  INFJ  80.138280  2021-09-24   6719.0
# 89   id89  34.0   경기   66.0   1    gold  ENTJ  33.308999  2021-10-14   6119.0
# 91   id91   6.0   경기   72.0   0    gold  INTP   9.796378  2021-08-23   8988.0
# 92   id92  97.0   경기   78.0   1    gold  INFP  97.381034  2021-05-08   9625.0
# 95   id95  77.0   경기   43.0   1    gold  INTJ  91.297791  2021-05-21   8697.0
# 96   id96  92.0   경기   53.0   1  silver  ENTJ  52.667078  2021-05-06   4336.0
# 99   id99   1.0   경기   47.0   0    gold  ESFJ  97.381034  2021-12-02   6090.0

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0), 밑으로 가# 면서 제거하니, 행을 제거하는 것임.
df = df.dropna()

# 2) 앞에서부터 70% 데이터 슬라이싱
df = df.iloc[:int(len(df)*0.7)]
# .iloc >> 정수기반 조회
print(df)
# Out:
#        id   age city     f1  f2      f3    f4         f5  subscribed    views
# 2    id03  27.0   서울   61.0   1    gold  ISTJ  17.252986  2021-03-16   7312.0
# 5    id06  22.0   서울   57.0   0     vip  INTP  20.129444  2021-09-12  21550.0
# 7    id08  38.0   서울  101.0   1  silver  INFJ  83.685380  2021-03-06   3260.0
# 9    id10  95.0   서울   74.0   1    gold  ISFP  98.429899  2021-04-03   9992.0
# 10  id100  47.0   경기   53.0   0     vip  ESFP  33.308999  2021-02-21  15535.0
# 11   id11  40.0   서울   68.0   0    gold  ENFP  98.429899  2021-10-29   6752.0
# 13   id13  15.0   서울   68.0   0    gold  ESFJ  83.685380  2021-12-30   5643.0
# 14   id14  77.0   서울   50.0   1    gold  ENTJ  67.886373  2021-09-19   5700.0
# 15   id15  22.0   서울   67.0   1    gold  ENTP   9.796378  2021-05-26   7676.0
# 16   id16  68.0   서울   85.0   0    gold  ESFP  16.283854  2021-07-25   9472.0
# 18   id18  41.0   서울   87.0   2    gold  ISFJ  80.138280  2021-03-03   7933.0
# 22   id22  -6.3   부산   72.0   1    gold  ENFP  52.667078  2021-02-09   6147.0
# 23   id23  34.0   부산   75.0   1    gold  ISTP  69.730313  2021-05-21   6236.0
# 24   id24  80.0   부산   44.0   0    gold  INFJ  73.586397  2021-09-11   5976.0
# 26   id26  55.0   부산   57.0   1    gold  ENFP  83.685380  2021-05-01   5857.0
# 27   id27  37.0   부산   60.0   0  silver  ESTP  73.586397  2021-10-13   4255.0
# 28   id28  38.0   부산   34.0   1    gold  ENTP  80.138280  2021-10-31   5068.0
# 29   id29 -13.5   부산   47.0   2    gold  ENTP  67.886373  2021-08-28   6793.0
# 31   id31  86.0   부산   77.0   0    gold  ESFJ  73.586397  2021-02-11   8014.0
# 32   id32  25.0   부산   64.0   0     vip  ISFJ  13.049921  2021-05-24  17421.0
# 33   id33  47.0   부산   94.0   0  silver  ENFJ  17.252986  2021-04-02   3880.0
# 36   id36  68.0   부산   77.0   1    gold  INTP  13.049921  2021-07-20   9713.0
# 40   id40  56.0   대구   75.0   0    gold  ENFP  17.252986  2021-01-22   8481.0
# 41   id41  81.0   대구   55.0   0    gold  ENFJ  37.113739  2021-10-04   8640.0
# 42   id42  65.0   대구   48.0   2    gold  ESTP  33.308999  2021-02-09   5999.0
# 43   id43  23.0   대구   60.0   0  silver  ISTP  29.269869  2021-05-18   3878.0
# 45   id45  97.0   대구   88.0   0    gold  ENFJ  13.049921  2021-06-21   8317.0
# 47   id47  34.6   대구   75.0   1    gold  ESTJ  90.496999  2021-05-28   8628.0
# 49   id49  75.0   대구   88.0   0    gold  INTP  37.113739  2021-03-31   9737.0
# 52   id52  97.0   대구   82.0   1    gold  ISFJ  90.496999  2021-05-20   8518.0
# 53   id53  52.0   대구   50.0   0    gold  ESTP  20.129444  2021-09-09   7012.0
# 55   id55  75.0   대구   63.0   2    gold  ENTP  13.049921  2021-02-06   6042.0
# 57   id57   3.0   대구  111.0   0  silver  ISFJ  29.269869  2021-01-12   4421.0
# 63   id63  88.0   경기   86.0   1  silver  ISFJ  73.586397  2021-12-01   4053.0
# 64   id64  43.0   경기   62.0   2    gold  ESFP  73.586397  2021-02-22   5995.0

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0), 밑으로 가# 면서 제거하니, 행을 제거하는 것임.
df = df.dropna()

# 2) 앞에서부터 70% 데이터 슬라이싱
df = df.iloc[:int(len(df)*0.7)]

# 3) 1사분위 값 계산(정수 출력)
print(int(df['f1'].quantile(.25)))
# .quantile >> 데이터 크기 순 정렬한 뒤 특정 비율(0~1)에 있는 값을 찾음
# Out:
# 57

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0), 밑으로 가# 면서 제거하니, 행을 제거하는 것임.
df = df.dropna()

# 2) 앞에서부터 70% 데이터 슬라이싱
df = df.iloc[:int(len(df)*0.7)]

# 3) 3 사분위 값 계산(정수 출력)
print(int(df['f1'].quantile(.75)))
# Out:
# 79

# %% [markdown]
# # [문제 4]

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치 수 컬럼별로 확인 및 변수에 대입(시리즈)
df_cntNull = df.isnull().sum()
# .isnull >> 결측치 위치 확인 // 결측치면 True 아니면 Fasle
# .isnull().sum() >> 컬럼별 결측치 개수 계산
print(df_cntNull)
# Out:
# id             0
# age            0
# city           0
# f1            31
# f2             0
# f3            28
# f4             0
# f5             0
# subscribed     0
# views          4
# dtype: int64

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치 수 컬럼별로 확인 및 변수에 대입(시리즈)
df_cntNull = df.isnull().sum()

# 2) 내림차순 정렬
df_cntNull = df_cntNull.sort_values(ascending=False)
# sort_values >> 값을 기준으로 레이블을 정렬
# ascending >> 오름차순 내림차순 설정 //  True = 오름차순 , False 내림차순
print(df_cntNull)
# Out:
# f1            31
# f3            28
# views          4
# id             0
# age            0
# city           0
# f2             0
# f4             0
# f5             0
# subscribed     0
# dtype: int64

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치 수 컬럼별로 확인 및 변수에 대입(시리즈)
df_cntNull = df.isnull().sum()

# 2) 내림차순 정렬
df_cntNull = df_cntNull.sort_values(ascending=False)

# 3) 가장 상위에 있는 인덱스명 출력
print(df_cntNull.index[0])
# Out:
# f1

# %% [markdown]
# # [문제 5]

# %%
import pandas as pd
# df = pd.read_csv("data4-1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-1.csv")

# 1) 3사분위수와 1사분위수의 차이를 절대값으로 계산
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
result = abs(q1 - q3)

print (q1,"\n",q3,"\n",result)
# Out:
# 26.875
#  77.0
#  50.125

# %%
import pandas as pd
# df = pd.read_csv("data4-1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-1.csv")

# 1) 3사분위수와 1사분위수의 차이를 절대값으로 계산
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
result = abs(q1 - q3)

# 2) 소수점 이하를 버리고, 정수로 출력
print(int(result))
# Out:
# 50

# %% [markdown]
# # [문제 6]

# %%
import pandas as pd
# df = pd.read_csv("data4-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-2.csv")

# 1) 비율이 40%보다 크고 50%보다 작은 조건
cond1 = (df['loves'] + df['wows']) / df['reactions'] > 0.4
cond2 = (df['loves'] + df['wows']) / df['reactions'] < 0.5

print(cond1,cond2)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7045    False
# 7046    False
# 7047     True
# 7048    False
# 7049    False
# Length: 7050, dtype: bool 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7045     True
# 7046     True
# 7047    False
# 7048     True
# 7049     True
# Length: 7050, dtype: bool

# %%
import pandas as pd
# df = pd.read_csv("data4-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-2.csv")

# 1) 비율이 40%보다 크고 50%보다 작은 조건
cond1 = (df['loves'] + df['wows']) / df['reactions'] > 0.4
cond2 = (df['loves'] + df['wows']) / df['reactions'] < 0.5

# 2) type이 video인 조건
cond3 = df['type'] == 'video'
print(cond3)
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 7045    False
# 7046    False
# 7047    False
# 7048    False
# 7049    False
# Name: type, Length: 7050, dtype: bool

# %%
import pandas as pd
# df = pd.read_csv("data4-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-2.csv")

# 1) 비율이 40%보다 크고 50%보다 작은 조건
cond1 = (df['loves'] + df['wows']) / df['reactions'] > 0.4
cond2 = (df['loves'] + df['wows']) / df['reactions'] < 0.5

# 2) type이 video인 조건
cond3 = df['type'] == 'video'

# 3) 조건에 맞는 데이터 수 구하기
print(len(df[cond1 & cond2 & cond3]))
# Out:
# 90

# %% [markdown]
# # [문제 7]

# %%
import pandas as pd
# df = pd.read_csv("data5-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch5/data5-2.csv")

# 1) bmi 파생변수 계산
df['bmi'] = df['Weight'] / (df['Height']/100)**2

print(df)
# Out:
#       Gender  Height  Weight        bmi
# 0       Male   187.6   109.7  31.170298
# 1       Male   174.7    73.6  24.115263
# 2       Male   188.2    96.5  27.245079
# 3       Male   182.2    99.8  30.063102
# 4       Male   177.5    93.6  29.708391
# ...      ...     ...     ...        ...
# 9995  Female   168.1    62.0  21.940992
# 9996  Female   170.4    77.5  26.690857
# 9997  Female   162.2    58.3  22.159852
# 9998  Female   175.3    74.3  24.178257
# 9999  Female   157.3    51.6  20.854139
#
# [10000 rows x 4 columns]

# %%
import pandas as pd
# df = pd.read_csv("data5-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch5/data5-2.csv")

# 1) bmi 파생변수 계산
df['bmi'] = df['Weight'] / (df['Height']/100)**2

# 2) 조건1. 정상체중 bmi
cond1 = (df['bmi'] >= 18.5) & (df['bmi'] < 23)

print(cond1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996    False
# 9997     True
# 9998    False
# 9999     True
# Name: bmi, Length: 10000, dtype: bool

# %%
import pandas as pd
# df = pd.read_csv("data5-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch5/data5-2.csv")

# 1) bmi 파생변수 계산
df['bmi'] = df['Weight'] / (df['Height']/100)**2

# 2) 조건1. 정상체중 bmi
cond1 = (df['bmi'] >= 18.5) & (df['bmi'] < 23)

# 3) 조건2. 위험체중 bmi
cond2 = (df['bmi'] >= 23) & (df['bmi'] < 25)
print(cond2)
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Name: bmi, Length: 10000, dtype: bool

# %%
import pandas as pd
# df = pd.read_csv("data5-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch5/data5-2.csv")

# 1) bmi 파생변수 계산
df['bmi'] = df['Weight'] / (df['Height']/100)**2

# 2) 조건1. 정상체중 bmi
cond1 = (df['bmi'] >= 18.5) & (df['bmi'] < 23)

# 3) 조건2. 위험체중 bmi
cond2 = (df['bmi'] >= 23) & (df['bmi'] < 25)

# 4) 조건1의 인원와 조건2의 인원 차이계산, 절대값 처리
print(abs(len(df[cond1]) - len(df[cond2])))
# Out:
# 144

# %% [markdown]
# # [문제 8]

# %%
import pandas as pd
# df = pd.read_csv("student_assessment.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch7/student_assessment.csv")

# 1) 결측치 제거
print(df.shape)
df = df.dropna()

print("\n",df)
# Out:
# (2565, 4)
#
#        id_assessment  student_id  study_period_days  score
# 0               103           0                 22   87.0
# 1                93           1                 70   92.0
# 2                15           2                 22    2.0
# 3               107           3                 22   51.0
# 4                72           4                 22   73.0
# ...             ...         ...                ...    ...
# 2560             96        2695                 35    3.0
# 2561             38        2696                 22   77.0
# 2562             87        2697                 22   88.0
# 2563             88        2698                 70   67.0
# 2564             50        2699                 22   24.0
#
# [2544 rows x 4 columns]

# %%
import pandas as pd
# df = pd.read_csv("student_assessment.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch7/student_assessment.csv")

# 1) 결측치 제거
df = df.dropna()

# 2) 가장 많이 수강한 과목 필터링
id = df['id_assessment'].value_counts().idxmax()
cond = df['id_assessment'] == id
df = df[cond]
#.idxmax >> 최대값을 가지는 레이블 출력
print(id,"\n",cond,"\n",df)
# Out:
# 12
#  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2560    False
# 2561    False
# 2562    False
# 2563    False
# 2564    False
# Name: id_assessment, Length: 2544, dtype: bool
#        id_assessment  student_id  study_period_days  score
# 80               12          85                 35   50.0
# 131              12         141                 70   32.0
# 342              12         365                 22   99.0
# 349              12         372                 22   49.0
# 368              12         394                 22   33.0
# 450              12         479                 35   68.0
# 513              12         543                 35   44.0
# 568              12         601                 22   21.0
# 926              12         981                 22   71.0
# 965              12        1023                 22   22.0
# 975              12        1033                 35   68.0
# 983              12        1042                 22   77.0
# 1141             12        1205                 35   18.0
# 1161             12        1225                 22   76.0
# 1203             12        1270                 70   12.0
# 1290             12        1362                 70   14.0
# 1291             12        1364                 22   72.0
# 1399             12        1477                 22   19.0
# 1480             12        1560                 70    4.0
# 1612             12        1701                 35   14.0
# 1642             12        1732                 35   11.0
# 1671             12        1764                 35   69.0
# 1813             12        1911                 70   10.0
# 1862             12        1963                 35    8.0
# 2051             12        2159                 70    3.0
# 2060             12        2170                 70   47.0
# 2080             12        2191                 22   34.0
# 2188             12        2309                 35   57.0
# 2225             12        2351                 70   84.0
# 2272             12        2399                 70   61.0
# 2309             12        2437                 22   39.0
# 2431             12        2562                 22   50.0
# 2548             12        2683                 22   37.0

# %%
import pandas as pd
# df = pd.read_csv("student_assessment.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch7/student_assessment.csv")

# 1) 결측치 제거
df = df.dropna()

# 2) 가장 많이 수강한 과목 필터링
id = df['id_assessment'].value_counts().idxmax()
cond = df['id_assessment'] == id
df = df[cond]

# 3) 과목 점수 스탠다드 스케일
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['score'] = scaler.fit_transform(df[['score']])
#scaler의 method 가 2차원인 dataframe 을 입력으로 사용

print(df['score'])
# Out:
# 80      0.319328
# 131    -0.365441
# 342     2.183422
# 349     0.281286
# 368    -0.327398
# 450     1.004097
# 513     0.091072
# 568    -0.783911
# 926     1.118226
# 965    -0.745868
# 975     1.004097
# 983     1.346482
# 1141   -0.898039
# 1161    1.308439
# 1203   -1.126295
# 1290   -1.050210
# 1291    1.156268
# 1399   -0.859996
# 1480   -1.430637
# 1612   -1.050210
# 1642   -1.164338
# 1671    1.042140
# 1813   -1.202381
# 1862   -1.278466
# 2051   -1.468680
# 2060    0.205200
# 2080   -0.289355
# 2188    0.585627
# 2225    1.612781
# 2272    0.737798
# 2309   -0.099142
# 2431    0.319328
# 2548   -0.175227
# Name: score, dtype: float64

# %%
import pandas as pd
# df = pd.read_csv("student_assessment.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch7/student_assessment.csv")

# 1) 결측치 제거
# print(df.shape)
df = df.dropna()

# 2) 가장 많이 수강한 과목 필터링
id = df['id_assessment'].value_counts().idxmax()
cond = df['id_assessment'] == id
df = df[cond]

# 3) 과목 점수 스탠다드 스케일
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['score'] = scaler.fit_transform(df[['score']])
#scaler의 method 가 2차원인 dataframe 을 입력으로 사용

# 4) 가장 큰 값
print(round(df['score'].max(), 3))
# Out:
# 2.183
